# %%
import pandas as pd
import numpy as np
from citipy import citipy
import requests

import time
from datetime import datetime

from config import weather_api_key

# %%
# create 2000 random lat/lng combos

lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# tuple coords

lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# create city list

cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 738

# %%
# create OpenWeatherAPI url

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# get weather data

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1
total_record_count = 1

# loop through cities

for i, city in enumerate(cities):
    # group cities in groups of 50
    
    if (i % 50 == 0 and i > 49):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # create endpoint URL
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log URL, record, and set numbers
    
    print(f"{total_record_count}: Processing Record {record_count} of Set {set_count} | {city}")
    
    # count request number for console
        
    record_count += 1
    total_record_count += 1
    
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# 1: Processing Record 1 of Set 1 | castro
# 2: Processing Record 2 of Set 1 | hilo
# 3: Processing Record 3 of Set 1 | huilong
# 4: Processing Record 4 of Set 1 | albany
# 5: Processing Record 5 of Set 1 | flinders
# 6: Processing Record 6 of Set 1 | ponta do sol
# 7: Processing Record 7 of Set 1 | myitkyina
# 8: Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# 9: Processing Record 9 of Set 1 | upernavik
# 10: Processing Record 10 of Set 1 | airai
# 11: Processing Record 11 of Set 1 | caravelas
# 12: Processing Record 12 of Set 1 | jamestown
# 13: Processing Record 13 of Set 1 | rikitea
# 14: Processing Record 14 of Set 1 | yellowknife
# 15: Processing Record 15 of Set 1 | hermanus
# 16: Processing Record 16 of Set 1 | mantua
# 17: Processing Record 17 of Set 1 | upata
# 18: Processing Record 18 of Set 1 | labuhan
# 19: Processing Record 19 of Set 1 | butaritari
# 20: Processing Record 20 of Set 1 | markova
# 21: Processing Record 21 of Set 1 | maneromango
# 22: Processing Record 22 of Set 1 | norman wells
# 23: Processing Record 23 of Set 1 | lompoc
# 24: Processing Record 24 of Set 1 | mataura
# 25: Processing Record 25 of Set 1 | tierralta
# 26: Processing Record 26 of Set 1 | portland
# 27: Processing Record 27 of Set 1 | ushuaia
# 28: Processing Record 28 of Set 1 | hobart
# 29: Processing Record 29 of Set 1 | bure
# 30: Processing Record 30 of Set 1 | ola
# 31: Processing Record 31 of Set 1 | san quintin
# 32: Processing Record 32 of Set 1 | bethel
# 33: Processing Record 33 of Set 1 | teya
# 34: Processing Record 34 of Set 1 | samarai
# 35: Processing Record 35 of Set 1 | port elizabeth
# 36: Processing Record 36 of Set 1 | vaini
# 37: Processing Record 37 of Set 1 | atuona
# 38: Processing Record 38 of Set 1 | kapaa
# 39: Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# 40: Processing Record 40 of Set 1 | cape town
# 41: Processing Record 41 of Set 1 | tucuman
# 42: Processing Record 42 of Set 1 | busselton
# 43: Processing Record 43 of Set 1 | meulaboh
# 44: Processing Record 44 of Set 1 | avera
# 45: Processing Record 45 of Set 1 | nanortalik
# 46: Processing Record 46 of Set 1 | bargal
# City not found. Skipping...
# 47: Processing Record 47 of Set 1 | bathsheba
# 48: Processing Record 48 of Set 1 | luderitz
# 49: Processing Record 49 of Set 1 | moore
# 50: Processing Record 50 of Set 1 | batagay-alyta
# 51: Processing Record 1 of Set 2 | derzhavinsk
# 52: Processing Record 2 of Set 2 | launceston
# 53: Processing Record 3 of Set 2 | bredasdorp
# 54: Processing Record 4 of Set 2 | biltine
# 55: Processing Record 5 of Set 2 | kaseda
# 56: Processing Record 6 of Set 2 | namibe
# 57: Processing Record 7 of Set 2 | guerrero negro
# 58: Processing Record 8 of Set 2 | gaspe
# 59: Processing Record 9 of Set 2 | olafsvik
# 60: Processing Record 10 of Set 2 | pisco
# 61: Processing Record 11 of Set 2 | punta arenas
# 62: Processing Record 12 of Set 2 | morden
# 63: Processing Record 13 of Set 2 | murupara
# 64: Processing Record 14 of Set 2 | bosaso
# 65: Processing Record 15 of Set 2 | puerto ayora
# 66: Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# 67: Processing Record 17 of Set 2 | nouadhibou
# 68: Processing Record 18 of Set 2 | pangnirtung
# 69: Processing Record 19 of Set 2 | bengkulu
# 70: Processing Record 20 of Set 2 | dieppe
# 71: Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# 72: Processing Record 22 of Set 2 | bluff
# 73: Processing Record 23 of Set 2 | khatanga
# 74: Processing Record 24 of Set 2 | paatan
# 75: Processing Record 25 of Set 2 | eenhana
# 76: Processing Record 26 of Set 2 | chagda
# City not found. Skipping...
# 77: Processing Record 27 of Set 2 | isangel
# 78: Processing Record 28 of Set 2 | saskylakh
# 79: Processing Record 29 of Set 2 | petropavlovsk-kamchatskiy
# 80: Processing Record 30 of Set 2 | tuktoyaktuk
# 81: Processing Record 31 of Set 2 | imeni babushkina
# 82: Processing Record 32 of Set 2 | hovd
# 83: Processing Record 33 of Set 2 | dudinka
# 84: Processing Record 34 of Set 2 | buraydah
# 85: Processing Record 35 of Set 2 | arraial do cabo
# 86: Processing Record 36 of Set 2 | tilichiki
# 87: Processing Record 37 of Set 2 | leningradskiy
# 88: Processing Record 38 of Set 2 | plettenberg bay
# 89: Processing Record 39 of Set 2 | mudgal
# 90: Processing Record 40 of Set 2 | baruun-urt
# 91: Processing Record 41 of Set 2 | saint-philippe
# 92: Processing Record 42 of Set 2 | avarua
# 93: Processing Record 43 of Set 2 | port alfred
# 94: Processing Record 44 of Set 2 | cherskiy
# 95: Processing Record 45 of Set 2 | kaeo
# 96: Processing Record 46 of Set 2 | maiduguri
# 97: Processing Record 47 of Set 2 | provideniya
# 98: Processing Record 48 of Set 2 | ambon
# 99: Processing Record 49 of Set 2 | bambous virieux
# 100: Processing Record 50 of Set 2 | dzilam gonzalez
# 101: Processing Record 1 of Set 3 | mbekenyera
# 102: Processing Record 2 of Set 3 | klaksvik
# 103: Processing Record 3 of Set 3 | okha
# 104: Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# 105: Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# 106: Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# 107: Processing Record 7 of Set 3 | fortuna
# 108: Processing Record 8 of Set 3 | new norfolk
# 109: Processing Record 9 of Set 3 | ketchikan
# 110: Processing Record 10 of Set 3 | qaanaaq
# 111: Processing Record 11 of Set 3 | challapata
# 112: Processing Record 12 of Set 3 | mar del plata
# 113: Processing Record 13 of Set 3 | cozumel
# 114: Processing Record 14 of Set 3 | cholet
# 115: Processing Record 15 of Set 3 | marsabit
# 116: Processing Record 16 of Set 3 | bandarbeyla
# 117: Processing Record 17 of Set 3 | tasiilaq
# 118: Processing Record 18 of Set 3 | chicama
# 119: Processing Record 19 of Set 3 | veraval
# 120: Processing Record 20 of Set 3 | chuy
# 121: Processing Record 21 of Set 3 | panaba
# 122: Processing Record 22 of Set 3 | zhitikara
# City not found. Skipping...
# 123: Processing Record 23 of Set 3 | palabuhanratu
# City not found. Skipping...
# 124: Processing Record 24 of Set 3 | barrow
# 125: Processing Record 25 of Set 3 | torbay
# 126: Processing Record 26 of Set 3 | tiksi
# 127: Processing Record 27 of Set 3 | kodiak
# 128: Processing Record 28 of Set 3 | conceicao do araguaia
# 129: Processing Record 29 of Set 3 | kuching
# 130: Processing Record 30 of Set 3 | marsa matruh
# 131: Processing Record 31 of Set 3 | toba
# 132: Processing Record 32 of Set 3 | dikson
# 133: Processing Record 33 of Set 3 | ostrovnoy
# 134: Processing Record 34 of Set 3 | ciras
# City not found. Skipping...
# 135: Processing Record 35 of Set 3 | carnarvon
# 136: Processing Record 36 of Set 3 | lerwick
# 137: Processing Record 37 of Set 3 | kinanah
# City not found. Skipping...
# 138: Processing Record 38 of Set 3 | kaitangata
# 139: Processing Record 39 of Set 3 | hamilton
# 140: Processing Record 40 of Set 3 | mareeba
# 141: Processing Record 41 of Set 3 | saint-augustin
# 142: Processing Record 42 of Set 3 | dien bien
# City not found. Skipping...
# 143: Processing Record 43 of Set 3 | katsuura
# 144: Processing Record 44 of Set 3 | galiwinku
# City not found. Skipping...
# 145: Processing Record 45 of Set 3 | lakes entrance
# 146: Processing Record 46 of Set 3 | kamenskoye
# City not found. Skipping...
# 147: Processing Record 47 of Set 3 | mahebourg
# 148: Processing Record 48 of Set 3 | ancud
# 149: Processing Record 49 of Set 3 | codrington
# 150: Processing Record 50 of Set 3 | myrtle beach
# 151: Processing Record 1 of Set 4 | cordoba
# 152: Processing Record 2 of Set 4 | talnakh
# 153: Processing Record 3 of Set 4 | husavik
# 154: Processing Record 4 of Set 4 | ilulissat
# 155: Processing Record 5 of Set 4 | hofn
# 156: Processing Record 6 of Set 4 | cayhagan
# 157: Processing Record 7 of Set 4 | viligili
# City not found. Skipping...
# 158: Processing Record 8 of Set 4 | eydhafushi
# 159: Processing Record 9 of Set 4 | port lincoln
# 160: Processing Record 10 of Set 4 | sambava
# 161: Processing Record 11 of Set 4 | palekh
# 162: Processing Record 12 of Set 4 | narsaq
# 163: Processing Record 13 of Set 4 | lebu
# 164: Processing Record 14 of Set 4 | chokurdakh
# 165: Processing Record 15 of Set 4 | sinnamary
# 166: Processing Record 16 of Set 4 | villa carlos paz
# 167: Processing Record 17 of Set 4 | tuatapere
# 168: Processing Record 18 of Set 4 | evensk
# 169: Processing Record 19 of Set 4 | henties bay
# 170: Processing Record 20 of Set 4 | esperance
# 171: Processing Record 21 of Set 4 | belyy yar
# 172: Processing Record 22 of Set 4 | halifax
# 173: Processing Record 23 of Set 4 | olinda
# 174: Processing Record 24 of Set 4 | havre-saint-pierre
# 175: Processing Record 25 of Set 4 | okhotsk
# 176: Processing Record 26 of Set 4 | hithadhoo
# 177: Processing Record 27 of Set 4 | severo-kurilsk
# 178: Processing Record 28 of Set 4 | ponta delgada
# 179: Processing Record 29 of Set 4 | cururupu
# 180: Processing Record 30 of Set 4 | pitsunda
# 181: Processing Record 31 of Set 4 | prince rupert
# 182: Processing Record 32 of Set 4 | binga
# 183: Processing Record 33 of Set 4 | tessalit
# 184: Processing Record 34 of Set 4 | kadykchan
# City not found. Skipping...
# 185: Processing Record 35 of Set 4 | qui nhon
# 186: Processing Record 36 of Set 4 | vaitupu
# City not found. Skipping...
# 187: Processing Record 37 of Set 4 | baykit
# 188: Processing Record 38 of Set 4 | ugoofaaru
# 189: Processing Record 39 of Set 4 | havelock
# 190: Processing Record 40 of Set 4 | sapele
# 191: Processing Record 41 of Set 4 | nikolskoye
# 192: Processing Record 42 of Set 4 | hay river
# 193: Processing Record 43 of Set 4 | cabo san lucas
# 194: Processing Record 44 of Set 4 | tacoma
# 195: Processing Record 45 of Set 4 | lavrentiya
# 196: Processing Record 46 of Set 4 | mecca
# 197: Processing Record 47 of Set 4 | souillac
# 198: Processing Record 48 of Set 4 | nisia floresta
# 199: Processing Record 49 of Set 4 | kindu
# 200: Processing Record 50 of Set 4 | ilovlya
# 201: Processing Record 1 of Set 5 | gao
# 202: Processing Record 2 of Set 5 | leh
# 203: Processing Record 3 of Set 5 | barcelos
# 204: Processing Record 4 of Set 5 | berdyuzhye
# City not found. Skipping...
# 205: Processing Record 5 of Set 5 | yulara
# 206: Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# 207: Processing Record 7 of Set 5 | burkhala
# City not found. Skipping...
# 208: Processing Record 8 of Set 5 | mutoko
# 209: Processing Record 9 of Set 5 | odienne
# 210: Processing Record 10 of Set 5 | baturaja
# 211: Processing Record 11 of Set 5 | miri
# 212: Processing Record 12 of Set 5 | morondava
# 213: Processing Record 13 of Set 5 | srednekolymsk
# 214: Processing Record 14 of Set 5 | hasaki
# 215: Processing Record 15 of Set 5 | aswan
# 216: Processing Record 16 of Set 5 | tarauaca
# 217: Processing Record 17 of Set 5 | faanui
# 218: Processing Record 18 of Set 5 | sale
# 219: Processing Record 19 of Set 5 | westport
# 220: Processing Record 20 of Set 5 | jiangyou
# 221: Processing Record 21 of Set 5 | yenagoa
# 222: Processing Record 22 of Set 5 | san onofre
# 223: Processing Record 23 of Set 5 | vaitape
# 224: Processing Record 24 of Set 5 | cidreira
# 225: Processing Record 25 of Set 5 | yermekeyevo
# 226: Processing Record 26 of Set 5 | elizabeth city
# 227: Processing Record 27 of Set 5 | kapit
# 228: Processing Record 28 of Set 5 | puerto escondido
# 229: Processing Record 29 of Set 5 | kenai
# 230: Processing Record 30 of Set 5 | hirara
# 231: Processing Record 31 of Set 5 | motygino
# 232: Processing Record 32 of Set 5 | broome
# 233: Processing Record 33 of Set 5 | pevek
# 234: Processing Record 34 of Set 5 | karamea
# City not found. Skipping...
# 235: Processing Record 35 of Set 5 | santa rita
# 236: Processing Record 36 of Set 5 | kloulklubed
# 237: Processing Record 37 of Set 5 | victor harbor
# 238: Processing Record 38 of Set 5 | mkushi
# 239: Processing Record 39 of Set 5 | marystown
# 240: Processing Record 40 of Set 5 | attawapiskat
# City not found. Skipping...
# 241: Processing Record 41 of Set 5 | koror
# 242: Processing Record 42 of Set 5 | providencia
# 243: Processing Record 43 of Set 5 | akyab
# 244: Processing Record 44 of Set 5 | agadir
# 245: Processing Record 45 of Set 5 | pimentel
# 246: Processing Record 46 of Set 5 | mount gambier
# 247: Processing Record 47 of Set 5 | saint george
# 248: Processing Record 48 of Set 5 | bilibino
# 249: Processing Record 49 of Set 5 | valle de allende
# 250: Processing Record 50 of Set 5 | berlevag
# 251: Processing Record 1 of Set 6 | paamiut
# 252: Processing Record 2 of Set 6 | ipixuna
# 253: Processing Record 3 of Set 6 | san vicente
# 254: Processing Record 4 of Set 6 | constitucion
# 255: Processing Record 5 of Set 6 | beloha
# 256: Processing Record 6 of Set 6 | mana
# 257: Processing Record 7 of Set 6 | darhan
# 258: Processing Record 8 of Set 6 | hatillo
# 259: Processing Record 9 of Set 6 | orange walk
# 260: Processing Record 10 of Set 6 | longyearbyen
# 261: Processing Record 11 of Set 6 | pitkyaranta
# 262: Processing Record 12 of Set 6 | deputatskiy
# 263: Processing Record 13 of Set 6 | aasiaat
# 264: Processing Record 14 of Set 6 | lagoa
# 265: Processing Record 15 of Set 6 | sosnovo-ozerskoye
# 266: Processing Record 16 of Set 6 | krasnik
# 267: Processing Record 17 of Set 6 | coihaique
# 268: Processing Record 18 of Set 6 | rocha
# 269: Processing Record 19 of Set 6 | college
# 270: Processing Record 20 of Set 6 | quatre cocos
# 271: Processing Record 21 of Set 6 | goderich
# 272: Processing Record 22 of Set 6 | borba
# 273: Processing Record 23 of Set 6 | clyde river
# 274: Processing Record 24 of Set 6 | alofi
# 275: Processing Record 25 of Set 6 | minden
# 276: Processing Record 26 of Set 6 | gola gokarannath
# 277: Processing Record 27 of Set 6 | polunochnoye
# 278: Processing Record 28 of Set 6 | georgetown
# 279: Processing Record 29 of Set 6 | huarmey
# 280: Processing Record 30 of Set 6 | sitka
# 281: Processing Record 31 of Set 6 | sur
# 282: Processing Record 32 of Set 6 | kavieng
# 283: Processing Record 33 of Set 6 | ust-karsk
# 284: Processing Record 34 of Set 6 | houma
# 285: Processing Record 35 of Set 6 | uruacu
# 286: Processing Record 36 of Set 6 | domoni
# 287: Processing Record 37 of Set 6 | hunza
# City not found. Skipping...
# 288: Processing Record 38 of Set 6 | vanderhoof
# 289: Processing Record 39 of Set 6 | saleaula
# City not found. Skipping...
# 290: Processing Record 40 of Set 6 | nizhneyansk
# City not found. Skipping...
# 291: Processing Record 41 of Set 6 | stoyba
# City not found. Skipping...
# 292: Processing Record 42 of Set 6 | mys shmidta
# City not found. Skipping...
# 293: Processing Record 43 of Set 6 | biritiba-mirim
# 294: Processing Record 44 of Set 6 | asau
# 295: Processing Record 45 of Set 6 | alenquer
# 296: Processing Record 46 of Set 6 | laramie
# 297: Processing Record 47 of Set 6 | macae
# 298: Processing Record 48 of Set 6 | kudahuvadhoo
# 299: Processing Record 49 of Set 6 | chute-aux-outardes
# 300: Processing Record 50 of Set 6 | port hawkesbury
# 301: Processing Record 1 of Set 7 | nishihara
# 302: Processing Record 2 of Set 7 | shieli
# 303: Processing Record 3 of Set 7 | linhares
# 304: Processing Record 4 of Set 7 | aykino
# 305: Processing Record 5 of Set 7 | ahipara
# 306: Processing Record 6 of Set 7 | adrar
# 307: Processing Record 7 of Set 7 | namatanai
# 308: Processing Record 8 of Set 7 | millinocket
# 309: Processing Record 9 of Set 7 | young
# 310: Processing Record 10 of Set 7 | uaua
# 311: Processing Record 11 of Set 7 | noyabrsk
# 312: Processing Record 12 of Set 7 | kefalos
# 313: Processing Record 13 of Set 7 | ribeira grande
# 314: Processing Record 14 of Set 7 | dunedin
# 315: Processing Record 15 of Set 7 | ribas do rio pardo
# 316: Processing Record 16 of Set 7 | danielskuil
# 317: Processing Record 17 of Set 7 | conil
# 318: Processing Record 18 of Set 7 | saint-francois
# 319: Processing Record 19 of Set 7 | key west
# 320: Processing Record 20 of Set 7 | oyonnax
# 321: Processing Record 21 of Set 7 | toktogul
# 322: Processing Record 22 of Set 7 | kampot
# 323: Processing Record 23 of Set 7 | tailai
# 324: Processing Record 24 of Set 7 | praia
# 325: Processing Record 25 of Set 7 | los llanos de aridane
# 326: Processing Record 26 of Set 7 | aberdeen
# 327: Processing Record 27 of Set 7 | beringovskiy
# 328: Processing Record 28 of Set 7 | grand centre
# City not found. Skipping...
# 329: Processing Record 29 of Set 7 | izhma
# 330: Processing Record 30 of Set 7 | evanston
# 331: Processing Record 31 of Set 7 | vila
# 332: Processing Record 32 of Set 7 | kavaratti
# 333: Processing Record 33 of Set 7 | kalundborg
# 334: Processing Record 34 of Set 7 | zherdevka
# 335: Processing Record 35 of Set 7 | kinston
# 336: Processing Record 36 of Set 7 | victoria
# 337: Processing Record 37 of Set 7 | sorland
# 338: Processing Record 38 of Set 7 | nome
# 339: Processing Record 39 of Set 7 | great falls
# 340: Processing Record 40 of Set 7 | presidencia roque saenz pena
# 341: Processing Record 41 of Set 7 | korla
# 342: Processing Record 42 of Set 7 | thompson
# 343: Processing Record 43 of Set 7 | aklavik
# 344: Processing Record 44 of Set 7 | toliary
# City not found. Skipping...
# 345: Processing Record 45 of Set 7 | boa vista
# 346: Processing Record 46 of Set 7 | acajutla
# 347: Processing Record 47 of Set 7 | cascais
# 348: Processing Record 48 of Set 7 | yanliang
# 349: Processing Record 49 of Set 7 | senador guiomard
# 350: Processing Record 50 of Set 7 | alice springs
# 351: Processing Record 1 of Set 8 | magdiwang
# 352: Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# 353: Processing Record 3 of Set 8 | marcona
# City not found. Skipping...
# 354: Processing Record 4 of Set 8 | villagarzon
# 355: Processing Record 5 of Set 8 | pochutla
# 356: Processing Record 6 of Set 8 | iqaluit
# 357: Processing Record 7 of Set 8 | witrivier
# City not found. Skipping...
# 358: Processing Record 8 of Set 8 | molteno
# 359: Processing Record 9 of Set 8 | benton harbor
# 360: Processing Record 10 of Set 8 | tual
# 361: Processing Record 11 of Set 8 | massafra
# 362: Processing Record 12 of Set 8 | xique-xique
# 363: Processing Record 13 of Set 8 | tumannyy
# City not found. Skipping...
# 364: Processing Record 14 of Set 8 | guilin
# 365: Processing Record 15 of Set 8 | fershampenuaz
# 366: Processing Record 16 of Set 8 | omboue
# 367: Processing Record 17 of Set 8 | boden
# 368: Processing Record 18 of Set 8 | east london
# 369: Processing Record 19 of Set 8 | pahalgam
# 370: Processing Record 20 of Set 8 | cockburn town
# 371: Processing Record 21 of Set 8 | bolonchen
# City not found. Skipping...
# 372: Processing Record 22 of Set 8 | celestun
# 373: Processing Record 23 of Set 8 | belton
# 374: Processing Record 24 of Set 8 | ituni
# City not found. Skipping...
# 375: Processing Record 25 of Set 8 | tautira
# 376: Processing Record 26 of Set 8 | mzimba
# 377: Processing Record 27 of Set 8 | ovsyanka
# 378: Processing Record 28 of Set 8 | hambantota
# 379: Processing Record 29 of Set 8 | labutta
# City not found. Skipping...
# 380: Processing Record 30 of Set 8 | ossora
# 381: Processing Record 31 of Set 8 | kruisfontein
# 382: Processing Record 32 of Set 8 | asyut
# 383: Processing Record 33 of Set 8 | arlit
# 384: Processing Record 34 of Set 8 | san joaquin
# 385: Processing Record 35 of Set 8 | muskego
# 386: Processing Record 36 of Set 8 | yuanping
# 387: Processing Record 37 of Set 8 | bay city
# 388: Processing Record 38 of Set 8 | karratha
# 389: Processing Record 39 of Set 8 | maragogi
# 390: Processing Record 40 of Set 8 | bar harbor
# 391: Processing Record 41 of Set 8 | wanning
# 392: Processing Record 42 of Set 8 | halalo
# City not found. Skipping...
# 393: Processing Record 43 of Set 8 | xining
# 394: Processing Record 44 of Set 8 | ibra
# 395: Processing Record 45 of Set 8 | toora-khem
# 396: Processing Record 46 of Set 8 | rio grande
# 397: Processing Record 47 of Set 8 | hami
# 398: Processing Record 48 of Set 8 | kirakira
# 399: Processing Record 49 of Set 8 | san patricio
# 400: Processing Record 50 of Set 8 | lasa
# 401: Processing Record 1 of Set 9 | loandjili
# 402: Processing Record 2 of Set 9 | salalah
# 403: Processing Record 3 of Set 9 | naze
# 404: Processing Record 4 of Set 9 | zalantun
# 405: Processing Record 5 of Set 9 | atasu
# 406: Processing Record 6 of Set 9 | malm
# 407: Processing Record 7 of Set 9 | laguna
# 408: Processing Record 8 of Set 9 | eskasem
# City not found. Skipping...
# 409: Processing Record 9 of Set 9 | nyurba
# 410: Processing Record 10 of Set 9 | egvekinot
# 411: Processing Record 11 of Set 9 | frolovo
# 412: Processing Record 12 of Set 9 | dalbandin
# 413: Processing Record 13 of Set 9 | cacu
# 414: Processing Record 14 of Set 9 | anadyr
# 415: Processing Record 15 of Set 9 | banda aceh
# 416: Processing Record 16 of Set 9 | crotone
# 417: Processing Record 17 of Set 9 | nemuro
# 418: Processing Record 18 of Set 9 | fort saint john
# City not found. Skipping...
# 419: Processing Record 19 of Set 9 | pestravka
# 420: Processing Record 20 of Set 9 | anito
# 421: Processing Record 21 of Set 9 | vestmannaeyjar
# 422: Processing Record 22 of Set 9 | komsomolskiy
# 423: Processing Record 23 of Set 9 | svetlaya
# 424: Processing Record 24 of Set 9 | port hedland
# 425: Processing Record 25 of Set 9 | sharjah
# 426: Processing Record 26 of Set 9 | taoudenni
# 427: Processing Record 27 of Set 9 | umzimvubu
# City not found. Skipping...
# 428: Processing Record 28 of Set 9 | villa de reyes
# 429: Processing Record 29 of Set 9 | galle
# 430: Processing Record 30 of Set 9 | acapulco
# 431: Processing Record 31 of Set 9 | loreto
# 432: Processing Record 32 of Set 9 | boende
# 433: Processing Record 33 of Set 9 | saint-pierre
# 434: Processing Record 34 of Set 9 | mayo
# 435: Processing Record 35 of Set 9 | lolua
# City not found. Skipping...
# 436: Processing Record 36 of Set 9 | bang krathum
# 437: Processing Record 37 of Set 9 | nizhniy kuranakh
# 438: Processing Record 38 of Set 9 | antalaha
# 439: Processing Record 39 of Set 9 | sarkand
# 440: Processing Record 40 of Set 9 | vila franca do campo
# 441: Processing Record 41 of Set 9 | cherepovets
# 442: Processing Record 42 of Set 9 | coahuayana
# 443: Processing Record 43 of Set 9 | prado
# 444: Processing Record 44 of Set 9 | gamba
# 445: Processing Record 45 of Set 9 | port augusta
# 446: Processing Record 46 of Set 9 | ixtapa
# 447: Processing Record 47 of Set 9 | ballina
# 448: Processing Record 48 of Set 9 | mukhen
# 449: Processing Record 49 of Set 9 | beruwala
# 450: Processing Record 50 of Set 9 | hunchun
# 451: Processing Record 1 of Set 10 | russell
# 452: Processing Record 2 of Set 10 | nosy varika
# 453: Processing Record 3 of Set 10 | siniscola
# 454: Processing Record 4 of Set 10 | salinopolis
# 455: Processing Record 5 of Set 10 | bonfim
# 456: Processing Record 6 of Set 10 | newcastle
# 457: Processing Record 7 of Set 10 | bejar
# 458: Processing Record 8 of Set 10 | belaya gora
# 459: Processing Record 9 of Set 10 | bagdarin
# 460: Processing Record 10 of Set 10 | saldanha
# 461: Processing Record 11 of Set 10 | buala
# 462: Processing Record 12 of Set 10 | bahia honda
# 463: Processing Record 13 of Set 10 | auki
# 464: Processing Record 14 of Set 10 | fukue
# 465: Processing Record 15 of Set 10 | harrison
# 466: Processing Record 16 of Set 10 | shenjiamen
# 467: Processing Record 17 of Set 10 | vao
# 468: Processing Record 18 of Set 10 | staryy nadym
# 469: Processing Record 19 of Set 10 | touros
# 470: Processing Record 20 of Set 10 | itoman
# 471: Processing Record 21 of Set 10 | tumba
# 472: Processing Record 22 of Set 10 | bubaque
# 473: Processing Record 23 of Set 10 | trofors
# 474: Processing Record 24 of Set 10 | hokitika
# 475: Processing Record 25 of Set 10 | segovia
# 476: Processing Record 26 of Set 10 | gurskoye
# City not found. Skipping...
# 477: Processing Record 27 of Set 10 | marquette
# 478: Processing Record 28 of Set 10 | cedar city
# 479: Processing Record 29 of Set 10 | garden city
# 480: Processing Record 30 of Set 10 | maarianhamina
# 481: Processing Record 31 of Set 10 | kahului
# 482: Processing Record 32 of Set 10 | gat
# 483: Processing Record 33 of Set 10 | eirunepe
# 484: Processing Record 34 of Set 10 | magadan
# 485: Processing Record 35 of Set 10 | fairbanks
# 486: Processing Record 36 of Set 10 | baghdad
# 487: Processing Record 37 of Set 10 | bulaevo
# 488: Processing Record 38 of Set 10 | muzhi
# 489: Processing Record 39 of Set 10 | oranjemund
# 490: Processing Record 40 of Set 10 | hervey bay
# 491: Processing Record 41 of Set 10 | marawi
# 492: Processing Record 42 of Set 10 | doha
# 493: Processing Record 43 of Set 10 | kalmunai
# 494: Processing Record 44 of Set 10 | liezen
# 495: Processing Record 45 of Set 10 | samfya
# 496: Processing Record 46 of Set 10 | warrnambool
# 497: Processing Record 47 of Set 10 | xunchang
# 498: Processing Record 48 of Set 10 | basco
# 499: Processing Record 49 of Set 10 | bara
# 500: Processing Record 50 of Set 10 | umea
# 501: Processing Record 1 of Set 11 | umm lajj
# 502: Processing Record 2 of Set 11 | kieta
# 503: Processing Record 3 of Set 11 | vardo
# 504: Processing Record 4 of Set 11 | maun
# 505: Processing Record 5 of Set 11 | ukiah
# 506: Processing Record 6 of Set 11 | cao bang
# 507: Processing Record 7 of Set 11 | sokoni
# 508: Processing Record 8 of Set 11 | sulangan
# 509: Processing Record 9 of Set 11 | thunder bay
# 510: Processing Record 10 of Set 11 | turukhansk
# 511: Processing Record 11 of Set 11 | fonte boa
# 512: Processing Record 12 of Set 11 | kontagora
# 513: Processing Record 13 of Set 11 | geraldton
# 514: Processing Record 14 of Set 11 | kebumen
# 515: Processing Record 15 of Set 11 | burlington
# 516: Processing Record 16 of Set 11 | stankov
# 517: Processing Record 17 of Set 11 | chimore
# 518: Processing Record 18 of Set 11 | florence
# 519: Processing Record 19 of Set 11 | moose factory
# 520: Processing Record 20 of Set 11 | harper
# 521: Processing Record 21 of Set 11 | pacific grove
# 522: Processing Record 22 of Set 11 | ampanihy
# 523: Processing Record 23 of Set 11 | stokmarknes
# 524: Processing Record 24 of Set 11 | kantunilkin
# 525: Processing Record 25 of Set 11 | nsoko
# 526: Processing Record 26 of Set 11 | shitanjing
# 527: Processing Record 27 of Set 11 | goure
# 528: Processing Record 28 of Set 11 | mehamn
# 529: Processing Record 29 of Set 11 | solovetskiy
# City not found. Skipping...
# 530: Processing Record 30 of Set 11 | fort frances
# 531: Processing Record 31 of Set 11 | port shepstone
# 532: Processing Record 32 of Set 11 | axim
# 533: Processing Record 33 of Set 11 | sobolevo
# 534: Processing Record 34 of Set 11 | bajram curri
# 535: Processing Record 35 of Set 11 | tynda
# 536: Processing Record 36 of Set 11 | payakumbuh
# 537: Processing Record 37 of Set 11 | mbacke
# City not found. Skipping...
# 538: Processing Record 38 of Set 11 | lata
# 539: Processing Record 39 of Set 11 | male
# 540: Processing Record 40 of Set 11 | gravelbourg
# 541: Processing Record 41 of Set 11 | christchurch
# 542: Processing Record 42 of Set 11 | chapais
# 543: Processing Record 43 of Set 11 | comodoro rivadavia
# 544: Processing Record 44 of Set 11 | parabel
# 545: Processing Record 45 of Set 11 | paoua
# 546: Processing Record 46 of Set 11 | songjianghe
# 547: Processing Record 47 of Set 11 | novyy urengoy
# 548: Processing Record 48 of Set 11 | winnemucca
# 549: Processing Record 49 of Set 11 | sorong
# 550: Processing Record 50 of Set 11 | spartanburg
# 551: Processing Record 1 of Set 12 | jumla
# 552: Processing Record 2 of Set 12 | san carlos de bariloche
# 553: Processing Record 3 of Set 12 | kandi
# 554: Processing Record 4 of Set 12 | tay ninh
# 555: Processing Record 5 of Set 12 | kuche
# City not found. Skipping...
# 556: Processing Record 6 of Set 12 | griffith
# 557: Processing Record 7 of Set 12 | sergeyevka
# 558: Processing Record 8 of Set 12 | machico
# 559: Processing Record 9 of Set 12 | urumqi
# 560: Processing Record 10 of Set 12 | grand gaube
# 561: Processing Record 11 of Set 12 | flin flon
# 562: Processing Record 12 of Set 12 | abiy adi
# City not found. Skipping...
# 563: Processing Record 13 of Set 12 | yialos
# City not found. Skipping...
# 564: Processing Record 14 of Set 12 | barabai
# 565: Processing Record 15 of Set 12 | bacuit
# City not found. Skipping...
# 566: Processing Record 16 of Set 12 | stekolnyy
# City not found. Skipping...
# 567: Processing Record 17 of Set 12 | sao filipe
# 568: Processing Record 18 of Set 12 | solnechnyy
# 569: Processing Record 19 of Set 12 | havre
# 570: Processing Record 20 of Set 12 | poum
# 571: Processing Record 21 of Set 12 | sinjar
# 572: Processing Record 22 of Set 12 | fare
# 573: Processing Record 23 of Set 12 | lulea
# 574: Processing Record 24 of Set 12 | north myrtle beach
# 575: Processing Record 25 of Set 12 | bonavista
# 576: Processing Record 26 of Set 12 | livingston
# 577: Processing Record 27 of Set 12 | gweta
# 578: Processing Record 28 of Set 12 | swan river
# 579: Processing Record 29 of Set 12 | ocean city
# 580: Processing Record 30 of Set 12 | saint-joseph
# 581: Processing Record 31 of Set 12 | praya
# 582: Processing Record 32 of Set 12 | siyabuswa
# 583: Processing Record 33 of Set 12 | mogadishu
# 584: Processing Record 34 of Set 12 | fort nelson
# 585: Processing Record 35 of Set 12 | half moon bay
# 586: Processing Record 36 of Set 12 | coquimbo
# 587: Processing Record 37 of Set 12 | nguiu
# City not found. Skipping...
# 588: Processing Record 38 of Set 12 | monte cristi
# City not found. Skipping...
# 589: Processing Record 39 of Set 12 | kirchhundem
# 590: Processing Record 40 of Set 12 | vastervik
# City not found. Skipping...
# 591: Processing Record 41 of Set 12 | tuy hoa
# 592: Processing Record 42 of Set 12 | verkhnevilyuysk
# 593: Processing Record 43 of Set 12 | port blair
# 594: Processing Record 44 of Set 12 | san cristobal
# 595: Processing Record 45 of Set 12 | owensboro
# 596: Processing Record 46 of Set 12 | belawan
# 597: Processing Record 47 of Set 12 | polovinnoye
# 598: Processing Record 48 of Set 12 | yatou
# 599: Processing Record 49 of Set 12 | mount pleasant
# 600: Processing Record 50 of Set 12 | riyadh
# 601: Processing Record 1 of Set 13 | kegayli
# City not found. Skipping...
# 602: Processing Record 2 of Set 13 | sept-iles
# 603: Processing Record 3 of Set 13 | maria aurora
# 604: Processing Record 4 of Set 13 | taltal
# 605: Processing Record 5 of Set 13 | almaznyy
# 606: Processing Record 6 of Set 13 | rockhampton
# 607: Processing Record 7 of Set 13 | wanaka
# 608: Processing Record 8 of Set 13 | porto novo
# 609: Processing Record 9 of Set 13 | phan thiet
# 610: Processing Record 10 of Set 13 | nuuk
# 611: Processing Record 11 of Set 13 | methoni
# 612: Processing Record 12 of Set 13 | mazeikiai
# 613: Processing Record 13 of Set 13 | andra
# 614: Processing Record 14 of Set 13 | pandan
# 615: Processing Record 15 of Set 13 | walvis bay
# 616: Processing Record 16 of Set 13 | port keats
# 617: Processing Record 17 of Set 13 | tari
# 618: Processing Record 18 of Set 13 | presidente epitacio
# 619: Processing Record 19 of Set 13 | rosario do sul
# 620: Processing Record 20 of Set 13 | kathmandu
# 621: Processing Record 21 of Set 13 | ahuimanu
# 622: Processing Record 22 of Set 13 | corinto
# 623: Processing Record 23 of Set 13 | hue
# 624: Processing Record 24 of Set 13 | dingle
# 625: Processing Record 25 of Set 13 | afrikanda
# 626: Processing Record 26 of Set 13 | nyrob
# 627: Processing Record 27 of Set 13 | sao joao da barra
# 628: Processing Record 28 of Set 13 | bonnyville
# 629: Processing Record 29 of Set 13 | diyarb najm
# 630: Processing Record 30 of Set 13 | havoysund
# 631: Processing Record 31 of Set 13 | pakokku
# 632: Processing Record 32 of Set 13 | camara de lobos
# 633: Processing Record 33 of Set 13 | seoul
# 634: Processing Record 34 of Set 13 | brae
# 635: Processing Record 35 of Set 13 | atambua
# 636: Processing Record 36 of Set 13 | matagami
# 637: Processing Record 37 of Set 13 | ranong
# 638: Processing Record 38 of Set 13 | poya
# 639: Processing Record 39 of Set 13 | dunkirk
# 640: Processing Record 40 of Set 13 | wuan
# 641: Processing Record 41 of Set 13 | acarau
# 642: Processing Record 42 of Set 13 | banmo
# City not found. Skipping...
# 643: Processing Record 43 of Set 13 | caxito
# 644: Processing Record 44 of Set 13 | byron bay
# 645: Processing Record 45 of Set 13 | tutoia
# 646: Processing Record 46 of Set 13 | weihai
# 647: Processing Record 47 of Set 13 | luoyang
# 648: Processing Record 48 of Set 13 | morgan city
# 649: Processing Record 49 of Set 13 | khonuu
# City not found. Skipping...
# 650: Processing Record 50 of Set 13 | makakilo city
# 651: Processing Record 1 of Set 14 | ati
# 652: Processing Record 2 of Set 14 | natal
# 653: Processing Record 3 of Set 14 | skjervoy
# 654: Processing Record 4 of Set 14 | lagos
# 655: Processing Record 5 of Set 14 | ferry pass
# 656: Processing Record 6 of Set 14 | hengshui
# 657: Processing Record 7 of Set 14 | grande prairie
# 658: Processing Record 8 of Set 14 | sungaipenuh
# 659: Processing Record 9 of Set 14 | nagato
# 660: Processing Record 10 of Set 14 | gawler
# 661: Processing Record 11 of Set 14 | pringsewu
# 662: Processing Record 12 of Set 14 | rungata
# City not found. Skipping...
# 663: Processing Record 13 of Set 14 | mutsamudu
# City not found. Skipping...
# 664: Processing Record 14 of Set 14 | khudumelapye
# 665: Processing Record 15 of Set 14 | rosarito
# 666: Processing Record 16 of Set 14 | luanda
# 667: Processing Record 17 of Set 14 | novikovo
# 668: Processing Record 18 of Set 14 | khani
# 669: Processing Record 19 of Set 14 | paita
# 670: Processing Record 20 of Set 14 | springbok
# 671: Processing Record 21 of Set 14 | benjamin hill
# 672: Processing Record 22 of Set 14 | saint-fabien
# City not found. Skipping...
# 673: Processing Record 23 of Set 14 | newton stewart
# 674: Processing Record 24 of Set 14 | holden
# 675: Processing Record 25 of Set 14 | moron
# 676: Processing Record 26 of Set 14 | tanggul
# 677: Processing Record 27 of Set 14 | svetlogorsk
# 678: Processing Record 28 of Set 14 | hohhot
# 679: Processing Record 29 of Set 14 | straumen
# 680: Processing Record 30 of Set 14 | do gonbadan
# 681: Processing Record 31 of Set 14 | dolbeau
# City not found. Skipping...
# 682: Processing Record 32 of Set 14 | jahrom
# City not found. Skipping...
# 683: Processing Record 33 of Set 14 | usinsk
# 684: Processing Record 34 of Set 14 | kodino
# 685: Processing Record 35 of Set 14 | black river
# 686: Processing Record 36 of Set 14 | flagstaff
# 687: Processing Record 37 of Set 14 | meteti
# 688: Processing Record 38 of Set 14 | galveston
# 689: Processing Record 39 of Set 14 | zhizdra
# 690: Processing Record 40 of Set 14 | progreso
# 691: Processing Record 41 of Set 14 | port-cartier
# 692: Processing Record 42 of Set 14 | silvassa
# 693: Processing Record 43 of Set 14 | colac
# 694: Processing Record 44 of Set 14 | pangody
# 695: Processing Record 45 of Set 14 | devonport
# 696: Processing Record 46 of Set 14 | vagur
# 697: Processing Record 47 of Set 14 | gabu
# 698: Processing Record 48 of Set 14 | boyolangu
# 699: Processing Record 49 of Set 14 | sciacca
# 700: Processing Record 50 of Set 14 | mandali
# 701: Processing Record 1 of Set 15 | opuwo
# 702: Processing Record 2 of Set 15 | naliya
# 703: Processing Record 3 of Set 15 | viedma
# 704: Processing Record 4 of Set 15 | sasaram
# 705: Processing Record 5 of Set 15 | kijang
# 706: Processing Record 6 of Set 15 | chancay
# 707: Processing Record 7 of Set 15 | novotroitskaya
# 708: Processing Record 8 of Set 15 | pokhara
# 709: Processing Record 9 of Set 15 | ozinki
# 710: Processing Record 10 of Set 15 | noumea
# 711: Processing Record 11 of Set 15 | red wing
# 712: Processing Record 12 of Set 15 | broken hill
# 713: Processing Record 13 of Set 15 | tartus
# 714: Processing Record 14 of Set 15 | bolungarvik
# City not found. Skipping...
# 715: Processing Record 15 of Set 15 | ayagoz
# 716: Processing Record 16 of Set 15 | killybegs
# 717: Processing Record 17 of Set 15 | northam
# 718: Processing Record 18 of Set 15 | yurginskoye
# 719: Processing Record 19 of Set 15 | rosita
# 720: Processing Record 20 of Set 15 | bambanglipuro
# 721: Processing Record 21 of Set 15 | vallenar
# 722: Processing Record 22 of Set 15 | altamira
# 723: Processing Record 23 of Set 15 | yanchukan
# City not found. Skipping...
# 724: Processing Record 24 of Set 15 | shakawe
# 725: Processing Record 25 of Set 15 | diapaga
# 726: Processing Record 26 of Set 15 | xichang
# 727: Processing Record 27 of Set 15 | khanino
# 728: Processing Record 28 of Set 15 | gemena
# 729: Processing Record 29 of Set 15 | fruitvale
# 730: Processing Record 30 of Set 15 | waspan
# 731: Processing Record 31 of Set 15 | malpe
# 732: Processing Record 32 of Set 15 | krasnyy yar
# 733: Processing Record 33 of Set 15 | bereda
# 734: Processing Record 34 of Set 15 | dong hoi
# 735: Processing Record 35 of Set 15 | tokomaru
# 736: Processing Record 36 of Set 15 | camacha
# 737: Processing Record 37 of Set 15 | kilmez
# City not found. Skipping...
# 738: Processing Record 38 of Set 15 | rawah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create dataframe and reorder columns

city_data_df_raw = pd.DataFrame(city_data)

city_data_df = city_data_df_raw[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 
                             'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]

city_data_df
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Castro      BR -24.7911  -50.0119     53.53        95          98
# 1        Hilo      US  19.7297 -155.0900     82.27        91         100
# 2     Huilong      CN  31.8111  121.6550     83.89        78          96
# 3      Albany      US  42.6001  -73.9662     82.81        47          74
# 4    Flinders      AU -34.5833  150.8552     52.88        73          81
# ..        ...     ...      ...       ...       ...       ...         ...
# 668    Bereda      ES  43.2686   -7.5406     71.15        88          99
# 669  Dong Hoi      VN  17.4833  106.6000     78.58        88         100
# 670  Tokomaru      NZ -40.4667  175.5000     57.04        96          39
# 671   Camacha      PT  33.0833  -16.3333     65.62        73          20
# 672     Rawah      IQ  34.4816   41.9093     89.78        19          61
#
#      Wind Speed Current Description
# 0          8.90     overcast clouds
# 1         11.50       moderate rain
# 2          4.61     overcast clouds
# 3          6.60       broken clouds
# 4         11.99          light rain
# ..          ...                 ...
# 668        1.95     overcast clouds
# 669        5.26     overcast clouds
# 670        1.01    scattered clouds
# 671        2.30          few clouds
# 672       13.67       broken clouds
#
# [673 rows x 9 columns]

# %%
# save dataframe to csv

city_data_df.to_csv("WeatherPy_Database.csv", index_label='City_ID')
